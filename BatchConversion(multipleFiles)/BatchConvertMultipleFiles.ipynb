# %%
END_INDEX=3

# replace with last file index: Ex. if last file is S (6).wav, set END_INDEX=6

# %%
CUSTOM_PHRASES = [ {
                    "value": "کاستاندا","boost": 10.0},
                    {"value": "شامن","boost": 5.0},
                    {"value": "فلوریندا","boost": 15.0},
                    {"value": "دون خوان","boost": 20.0},
                    {"value": "دون خنارو","boost": 20.0},
                    {"value": "تولتک","boost": 15.0},
                    {"value": "تولنکهای کهن","boost": 12.0},
                    {"value": "دقت اول","boost": 12.0},
                    {"value": "دقت دوم","boost": 12.0}
                    ]

# %%
# Prepare the environment
import io
import os
import subprocess
import time

from docx import Document
import IPython.display as ipd
from etils import epath as ep
from google.api_core.client_options import ClientOptions
from google.cloud.speech_v2 import SpeechClient
from google.cloud.speech_v2.types import cloud_speech
import jiwer
import pandas as pd
import plotly.graph_objs as go
from pydub import AudioSegment
import os 

PROJECT_ID = "glassy-groove-461110-u0" 

LOCATION = os.environ.get("GOOGLE_CLOUD_REGION", "europe-west4")
BUCKET_NAME = "blob_speech"  # @param {type:"string", isTemplate: true}
BUCKET_URI = f"gs://{BUCKET_NAME}"  # @param {type:"string"}

print(f"Using project {PROJECT_ID} in location {LOCATION}")
print(f"Using bucket {BUCKET_URI} to convert {FILE_NAME} to text")
# Out:
# Using project verdant-branch-457906-a2 in location europe-west4
# Using bucket gs://bdav42 to convert S (2).wav to text

# %%
from google.cloud import storage

client = SpeechClient(
    client_options=ClientOptions(
        api_endpoint=f"{LOCATION}-speech.googleapis.com",
    )
)
storage_client = storage.Client()
RECOGNIZER = client.recognizer_path(PROJECT_ID, LOCATION, "_")
INPUT_LONG_AUDIO_SAMPLE_FILE_URI = ""

# %%
def read_audio_file(audio_file_path: str) -> bytes:
    """
    Read audio file as bytes.
    """
    if audio_file_path.startswith("gs://"):
        with ep.Path(audio_file_path).open("rb") as f:
            audio_bytes = f.read()
    else:
        with open(audio_file_path, "rb") as f:
            audio_bytes = f.read()
    return audio_bytes

def parse_batch_recognize_response(
    response, audio_sample_file_uri: str = INPUT_LONG_AUDIO_SAMPLE_FILE_URI
) -> list[tuple[str, int]]:
    """Parse batch responses from the Speech-to-Text API"""
    batch_recognize_results = []
    for result in response.results[
        audio_sample_file_uri
    ].inline_result.transcript.results:
        batch_recognize_results.append(
            (result.alternatives[0].transcript, result.result_end_offset)
        )
    return batch_recognize_results

# %%
for i in range(1, END_INDEX + 1):
    FILE_NAME = f"S ({i}).wav"
    INPUT_LONG_AUDIO_SAMPLE_FILE_URI = (f"{BUCKET_URI}/Spch2txt/AudioInput/{FILE_NAME}")
    blob = storage_client.bucket(BUCKET_URI.replace("gs://", "")).blob(f"Spch2txt/AudioInput/{FILE_NAME}")
    if not blob.exists():
        print(f"Error: File '{BUCKET_URI}/Spch2txt/AudioInput/{FILE_NAME}' does not exist in Google Cloud Storage.")
        exit(1)  # Stop execution if file is missing
    
    ### Perform batch recognition
    batch_recognition_config = cloud_speech.RecognitionConfig(
            auto_decoding_config=cloud_speech.AutoDetectDecodingConfig(),
            language_codes=["fa-IR","en-US"],
            model="chirp_2",
            # Use model adaptation
            adaptation=cloud_speech.SpeechAdaptation(
            phrase_sets=[
                cloud_speech.SpeechAdaptation.AdaptationPhraseSet(
                    inline_phrase_set=cloud_speech.PhraseSet(phrases=CUSTOM_PHRASES)
                )
            ]
            )
        )
    # Set the audio file URI
    audio_metadata = cloud_speech.BatchRecognizeFileMetadata(
        uri=INPUT_LONG_AUDIO_SAMPLE_FILE_URI)
    # Create the request
    batch_recognition_request = cloud_speech.BatchRecognizeRequest(
        config=batch_recognition_config,
        files=[audio_metadata],
        recognition_output_config=cloud_speech.RecognitionOutputConfig(
            inline_response_config=cloud_speech.InlineOutputConfig(),
        ),
        recognizer=RECOGNIZER,
    )
    # Run the batch recognition operation
    operation = client.batch_recognize(request=batch_recognition_request)
    while True:
        if not operation.done():
            print(f"Waiting for transcribing {FILE_NAME} to complete...")
            time.sleep(60)
        else:
            print(f"Operation completed for {FILE_NAME}.")
            break
    response = operation.result()
    batch_recognize_results = parse_batch_recognize_response(response, audio_sample_file_uri=INPUT_LONG_AUDIO_SAMPLE_FILE_URI)
    print(batch_recognize_results)
    type(batch_recognize_results)# Save the results to a Word document
    document = Document()
    document.add_heading(f'Persian Translation Results {FILE_NAME}', level=0)

    for transcription, duration in batch_recognize_results:
        document.add_paragraph(transcription)
        # document.add_paragraph(f"Duration: {duration}")   # Optional: Add duration if needed# 
        document.add_paragraph() # Add an empty paragraph for spacing   

    document.save(f'{FILE_NAME[:-4]}.docx')
    print(f"Persian translation saved to {FILE_NAME}.docx")
print("🎉 All files processed!")
# Out:
# Waiting for transcribing S (1).wav to complete...
# Waiting for transcribing S (1).wav to complete...
# Waiting for transcribing S (1).wav to complete...
# Waiting for transcribing S (1).wav to complete...
# Waiting for transcribing S (1).wav to complete...
# Waiting for transcribing S (1).wav to complete...
# Waiting for transcribing S (1).wav to complete...
# Waiting for transcribing S (1).wav to complete...
# Operation completed for S (1).wav.
# [('محاسبه نمیکنم بزن خرداد و خرداد آها تو این یه جای خوب پیدا کنم ویدیو رو بگیرم آره با موسیقی های زیبا بگیر که موسیقی هم پخش میشه حتماً یادگار بمونه پس نگاه کن پس اول ولیوه', datetime.timedelta(seconds=30)), ('ولیو میره رو هدف هدف پراجکت حالا بعضی وقتا یه پراجکت چند تا ساب پراجکت میشه یا مینی پراجکت میشه یا هم نباشه بعد میشن تسک تسک میشه دیوی اسکچول حالا مثلا فرض کن من میخوام پیشرفت کنم به فرض میخوام مهاجرت کنم میخوام برم امریکا', datetime.timedelta(seconds=60)), ('می\u200cخوام برم کانادا می\u200cخوام برم یه جایی این هدفه ولی چه ولیویی داره ولیوش اینه که من می\u200cخوام به آزادی برسم من نمی\u200cخوام دیگه جایی باشم که مثلاً به فرض خفه خان باشد فلان باشد می\u200cدونی چی می\u200cخوام بگم اون ولیو اولیش ولیو بعد اینو به یک هدف ترجمه\u200cش می\u200cکنی بعد اون هدف رو می\u200cگی آقا من الان می\u200cخوام برم یه زبان امتحان زبان می\u200cدم اینجا می\u200cشینم این دوره رو می\u200cخونم این مدرک رو می\u200cگیرم فلان می\u200cگم یه دفعه می\u200cبینی که اون', datetime.timedelta(seconds=90)), ('گل به چند تا پراجکت تقسیم میشه و هر کدوم از اون پراجکت ها یه سری تسک دارن بعد در طول روز اون تسک ها به عنوان دیلی اسکجول من شروع میکنم مثلا یه ساعت در روز میخونم نمیدونم فلان جا میرم ورزش میکنم نمیدونم فلانی رو میبینم با اون یکی صحبت میکنم با اونجا سفر میکنم اینا میشن حالا وقتی من دارم مدیتیت میکنم', datetime.timedelta(seconds=120)), ('ما اولین کاری که باید بکنیم باید بتونیم اون روحیات رو در خودمون احساس کنیم یعنی من آزادی رو من باید یه تصوری از آزادی داشته باشم یه تصوری باید از عشق داشته باشم درسته احساس دوست داشته شدن احساس دوست داشتن بعد جالب اینه که ما میگیم تو زندگی یه چیزی رو میگن انسان هر هدفی بخواد بهش میرسه انسان', datetime.timedelta(seconds=150)), ('هر هدفی رو که بخواد اکزکتلی شاید به اون هدف نرسه و ولی به ولیویی که پشت اون هست حتما خواهد رسید مثل اینکه من مثلا میخوام برم با یه دختری ازدواج کنم این یه هدفه ولی تو با این دختر ازدواج کنی میخوای به چی برسی میگی من به احساس بیلانگی میخوام برسم به احساس خواستنی بودن خواستنی شدن دوست داشتن میخوام برسم آره شاید این آدم نباشه یه آدم دیگه باشه ولی تو این ولیوها رو خواهی رسید متوجهی چی میخوام بگم ولی خب شاید اون هدف خاص نباشه مثلا', datetime.timedelta(seconds=180)), ('مثلا من این ماشینو میخوام بخرم شاید اصلا اون موقع شما این ماشینو میخوای بخرین این ماشین اصلا اوت اف مارکت باشه ولی شما این ماشین بهتری یا یه چیز دیگه ای یا اصلا یه زمانی یه چیز دیگه ای باشه برای همین جالبه بگیرم قشنگه آره', datetime.timedelta(seconds=210)), ('این خیلی جالبه که ممکنه آدم دقیقاً به اون هدف نرسه ولی به اون ولیو میرسه آفرین چرا به اون ولیو میرسه به خاطر اینکه میگفت ولیو درونیه هدف بیرونیه تو در واقع ولیو یه جایگاهی در پیوندگاه است میدونی تو برای اینکه بتونی به اون جایگاه در پیوندگاه برسی در بیرون باید یه اتفاقی بیفته این جای جابجایی', datetime.timedelta(seconds=240)), ('اتفاق بیفته ارتباط ولیو با آرکی تایپی چیه چی آرکی تایپی با ولیو آرکی تایپی منظورت چیه کدوم آرکی تایپی خب مثلا ما تو آرکی تایپی ها چیزای اسطوره ای زیاد میبینیم و مثلا خب ما نگاه کنید یه آرکی تایپی داریم بهش آرکی تایپی نیست ولی بهش میگم مثلا میگن آرکی تایپی یا مثلا نمیدونم آفرودیت منظورت ایناست یا نه آرکی تایپی های یونگ', datetime.timedelta(seconds=270)), ('مارکیتایپی های یونگی به عنوان مثلا بلاک های آنکانشس لاین که بخواد مثلا بیا عقب بری خودت بگیری بهتره چقدر مشکله آره آره خیلی راحت میشه آرکیتایپی ها هم حتی اسطوره ها هم یه قسمت از چیزایی که ما زندگی میکنیم میدونید چی میخوام', datetime.timedelta(seconds=300)), ('بگم یعنی ما آرکی تایپی ها چیزایی اند که میگه بابا خیلی جالب دیگه یه قسمت از شکل انسان آها مثل اون ناخودآگاه جمعی میشه از اشکال انسان', datetime.timedelta(seconds=330)), ('انسانی اند حتی ولی ها هم از اشکال انسانی اند من یه جایی به کی گفتم دوستشه نمیدونم آروین بوده کی بوده یه جمله ای برگشتم گفتم که مفهومش اینه که انسان باید به چی بچسبه یعنی به یه چیزی ارزش چسبیدن داره چرا آدم های مذهبی دنبال خدا هستن تو اگه آدم هیچ حبابی نداره', datetime.timedelta(seconds=342, microseconds=500000)), ('داشته باشه که میمیره که خیلی خیلی ساده تر از این حرفاست ما پیور سلف ما شکل انسانی رو ما یه قالب انسانی داریم یه شکل انسانی داریم هیومن فورم در واقع همون آرکیتایلیا اوکی که  ...
# Persian translation saved to S (1).wav.docx
# Waiting for transcribing S (2).wav to complete...
# Waiting for transcribing S (2).wav to complete...
# Waiting for transcribing S (2).wav to complete...
# Operation completed for S (2).wav.
# [('فیر آبجکت نداره وری زمانی که ترس آبجکت داره مثلا دارم میگم فرض کن شما فردا امتحان داری پس فردا امتحان داری الان ترسی نداری ولی به فردا داری فکر میکنی این میشه وری بعد یه زمانی رفتی تو آسانسور داری پنیک میکنی دیگه اینجا کل محیط ترسه میشه اگزایتی شما میری تو جنگل تو تاریکی هر لحظه از هر یه جایی میتونه کسی وارد', datetime.timedelta(seconds=30)), ('به درتو در بیاری این میشه انگزایتی ما معمولا برای اینکه انگزایتی رو تحمل کنیم انگزایتی رو به چی تبدیل میکنیم به ووری چرا چون ووری به ما جهت میده فرصت میده فردا دارم پس تا فردا فاصله دارم این منو نگران میکنه این درخت منو نگران نمیکنه این منو میترسونه این منو نمیترسونه ولی انگزایتی نیست من یه جایی میرم از هر جایی ممکنه یه ضربه بهم وارد بشه و این بچه بچه از تاریکی میترسه', datetime.timedelta(seconds=60)), ('به خاطر اینکه نمیدونه از کجا ضربه میخوره نمیدونه از کجا میاد مرگ مفهومش اینه برای همین انسان ها میان و انگزایتی رو به وری تبدیل میکنن درست شده این مکانیسمه حالا ما وقتی وری داشته باشیم وری ها معمولا ما وقتی که میخوایم مثلا میگفت تو تکای کهن چیکار میکردن میگفت ترس و تقسیم میکردن آره در واقع جمله اش اینه انگزایتی رو', datetime.timedelta(seconds=90)), ('به بری تبدیل میکردن ۲۰ تا بری میکردن می انداختن تو جون یکی میدونی چی میخوام بگم یعنی خیلی چیز خاصی نیست یعنی میگه حرفایی که میزنه خیلی زیباست آره ولی فهمش خیلی جالب تره وقتی میفهمی رو باید عجب چیز جالبیه حالا این چه ربطی به مسئله یک داره تو مسئله یک نگاه کن ما ما هزار چیز تو ذهنمون میاد یعنی ما مثلا الان مامانم الان پول داره تو انگلیس یا نداره من الان سر کارم اینجوریه کارم از دست', datetime.timedelta(seconds=120)), ('میدم نمیدم الان مصاحبه قبول میشم یا نمیشم من مثلا فرض کن لایسنس هم چه جوریه این دیگه فلانه تو بی چی میشه اینا امروز این کارو انجام بدم یا نه نگاه کن ما معمولا تو گفتگوی درونی هی چیزای مختلف میاد تو ذهن ما آره', datetime.timedelta(seconds=150)), ('تو مستری یک ما کاری که میکنیم یه این باکس ما در واقع ذهنمون رو خالی میکنیم یعنی یه دفتر قلم هست هر چون الان میخوای بشینی بنویسی در مورد افکارت هیچ فکری به ذهنت نمیاد میاد گوشه گوشه ها قایم میشه ولی شما یه کاغذ قلم داری هر چی اومد اینجا مینویسی هر چی به ذهنت اومد اینجا بنویس اصلا مهم نیست چیه میدونی مثلا من با وزنم مشکل دارم مینویسم من با پول درآوردنم نمیدونم خوابم نمیدونم', datetime.timedelta(seconds=180)), ('هر چیزی هر چیزی که میاد رو من اونجا مینویسم این باکس رو خب مثلا امروز برم فلان کارو انجام بدم درست بله و این این باکس باید تکلیفش مشخص بشه یه سری حالا من اینا رو دارم کامل میکنم که دارم همینجوری میگم یه سری حالا میتونید روش کار کنید به من ایده هم بدین دقیقا یه سری هستش که من کارا رو انجام میدم تموم میشه میره خط میخوره', datetime.timedelta(seconds=210)), ('تو آخر روز تموم میشه بعد یا در آخر هفته یعنی یه زمان هایی اینا میان به سه تا موضوع باید تبدیل بشن اوکی یه سری هستن که اینا جزو روند کارن یعنی من اینا رو باید بپذیرم تو زندگی من وجود داره مثل اینکه من بی خوابی دارم جزو تویت', datetime.timedelta(seconds=240)), ('منه درمان منه دارم کارشو انجام میدم یا فلان یا نه یه زمانی هست نه باید یه کاری باید براش انجام بدم درسته یه سری چیزا هستن که پس دسته اول میشه چی دیس از وات ایتیس همینه حالا یا خودش خود به خود خوب میشه برطرف میشه باید صبر کنی یا اینکه اصلا همیشه هست من پدرم فوت شده هست دیگه ببخشید', datetime.timedelta(seconds=270)), ('دست دوم اونهایی اند که ما اونها رو داریم به خاطر اینکه ما در یه جایی یه مشکلی رو باهاش دیل نمیکنیم که این داره میزنه بیرون ما باید یه چیزایی رو تمیز کنیم یه چیزایی رو کلینز کنیم یه چیزایی رو کلین کنیم ما باید یه چیزایی رو درست شد پس این میشه دسته دوم مثلا اسکیل ندارم که مثلا کار پیدا کنم مثلا من مشکل', datetime.timedelta(seconds=300)), ('سلف استیم دارم طرف یه چیزی به من میگه بهم برمیخوره چرا که من ناراحت شدم آقا به من بگو سلف استیمتو درست کنی درسته دست سوم چیزایی هستن که من', datetime.timedelta(seconds=330)), ('اینجا برید بیرون دقیقاً آره دسته سوم چیزایی اند که من یا دسته اول در واقع باید یا باید فیکسشون کنم یا جز زندگی هم باید شروعشون کنم باید یه دسته یکی باشن یا دسته دویی باشن ولی به دلایلی من این نمیتونم این کارو بکنم این دلایل نباید', datetime.timedelta(seconds=342, microseconds=500000)), ('نباید به خاطر ترس باشه نباید به خاطر تنبلی باشه یا به خاطر باوره ...
# Persian translation saved to S (2).wav.docx
# Waiting for transcribing S (3).wav to complete...
# Waiting for transcribing S (3).wav to complete...
# Operation completed for S (3).wav.
# [('ولی برای مولوی تو محله یک اتفاق افتاد یه دفعه ما جلو اسبشو گرفتیم اینو ریکورد کنید خوردم ستمگر میخوای خب پس خوردم ستمگر بعضی وقتا از مستری یک میاد یه زمانی از مستری ۱۱ ببین چقدر شیک توضیح میده اصلا اینقدر قشنگ اینا رو تو یعنی بهت بگم حالا یه چیز جالب داره', datetime.timedelta(seconds=30)), ('تمام این چیزایی که خوندین توشه همش اصلا هفت سنگ و ۱۲ مستری چیزی در کتاب های خوان من تا حالا نتونستم من خودم چون من پیدا کنم اینجا اینجا نباشه واقعیتش هفت اصل کمین و شکار توش هست چهار خوی جنگجو توش هست چهار دشمن توش هست اینکه شما باید خورده سمگر مواجه میشی سه تا گیفت بهت میده توش هست', datetime.timedelta(seconds=60)), ('یعنی هرچی بگی یعنی مؤثر این کتاب به صورت کلاسیک مرتب تو اینا وجود داره پس خرس همگر میشه یه نیرویی که از بیرون وارد میشه و به ما تحرک میده میاد انرژی میده به ما این باعث میشه ما اول رکگنازش میکنیم و بعد باید یادش بگیریم مسیر دو درست', datetime.timedelta(seconds=90)), ('آره و اون گارد درست رو تو مسیر سه در برابرش میگیریم حالا اصولی که داریم میگه میگه خرس زمگر چه داستانایی داره میگه خرس زمگر بحثش میدونید چیه دیگه شش تا المنت داره بله یه دونه اش بیرونی یه دونه اش چهار تاش درونی یه دونه اش مال ناشناخته است بله خب قسمت اراده اش میشه همون', datetime.timedelta(seconds=120)), ('اون اراده دو یعنی ما گفتیم اراده دو تاست دیگه از من تو سوال کرده بودی گفتی که یه اراده ما صحبت میکنیم در خودآگاه ماست یه اراده در ناخودآگاه ماست اساسا خرده ستمگر فعال کردن اراده ناخودآگاه است اوکی تمام بحثش اینه یعنی ناخودآگاه شروع میکنه به فعال شدن مثل اینکه تو راه میگفتین صبر کن آره دیگه وار خودشو میکنه برای اینکه اون فعال بشه ما باید یه نیرو محرکه داشته باشیم', datetime.timedelta(seconds=150)), ('به ما برخورد کنه که میشه خورده ستم کرد وقتی میگه میگه چهار تا خصوصیت در ما شکل میگیره ماشین هم خواستین میتونین روشن باشه میتونین خاموش باشه خودش خاموش میشه خب آره بعد چهار تا خصوصیت داریم دو تا دو تا کلا میشه چهار تا دو تاش مرحله اوله دو تاش مرحله دومه میدونی چه', datetime.timedelta(seconds=180)), ('دیدید بچه ها که اول میشینن سوال میکنن میرن پشت بقیه قایم میشن آره مرحله اول عکس پنس بود نه تو خوردی دیدم گرم اینکه حریفتو بشناسی نه چهار تا زنگی چهار تا داستان داره چهار تا خصوصیت در موردش شکل میگیره انضباط و شک گایی و سو آفرین داری نزدیک میشی اول انضباط نه اونا آ بذار اونا رو بهت بگم اینا از', datetime.timedelta(seconds=210)), ('جدا کنم در برخورد با مردم چهار تا خصوصیت باید داشته باشیم چیه سویتنس بله پیشنس پیشنس بی رحمی و هینه گری و هینه گری یا کانینگنس اونم توی ۱۲ مصدری هست نگران نباشید بریم روی خورزن خورزن همگر چهار تاست خویشتن داری انضباط خویشتن داری انضباط ایناست درسته', datetime.timedelta(seconds=240)), ('و بعد وقتی یه مقدار انرژی جمع میکنی شکیبایی و تایمینگ درسته منظورش چیه میگه وقتی با خود زنگر مواجه میشی باید دیسیپلین داشته باشی دیسیپلین یعنی نقطه ضعف های خود رو بشناسی نقطه ضعف های طرف مقابل رو بشناسی و اینا رو عمل کنی یعنی مستری دو اینا رو بشناسی درسته و بری عمل کنی یعنی تو مایند فولنت تو تمام مستری ها تو دیسیپلین رو زندگی', datetime.timedelta(seconds=270)), ('میکنی متوجه شدی چی میخوام بگم یعنی اون چیزی که به عنوان دیسیپلین میگه من خیلی بیشتر بازش کردم چرا چون مباحث دیگه هم گذاشتم توش چون من خودم فکر میکنم که چون اینا رو نگاه کن مفاهیم درستن اینکه دون خوان اینا کاستاندا اینا رو چقدر گفته بر اساس حالا دانشش تجربه اش بر اساس چی خودش گفته میدونی من اینا رو بردم نگاه کن من اینا رو بردم رو تمامیت هستی رو تمامیت هستی کاری که کاستاندا نکرد', datetime.timedelta(seconds=300)), ('زندگی می\u200cدونی من اینا رو تو تمامیت هستی تعریف می\u200cکنم تمامیت هستی یعنی اون هشت تا نقطه آره من نقطه هفت و هشت رو کردم هفت گذاشتم چی بعد پنج و شش و هفت هم به عنوان ناخود به عنوان دقت', datetime.timedelta(seconds=330)), ('دوم گذاشتم اونور اومدم رو دقت یک همه اینا رو تو هفت سنگ گفتم تو تمامیت بعد رو این چهار تا تو این چهار تا اومدم خدا آقا رو دارم توضیح میدم حالا رو این چهار تا چه چیزایی اند بریم سراغ خرد سنگ گرد پس اولیش شد انضباط و خویشتن داری خویشتن داری به معنا اینه که شما در حالی که داری کاراتو انجام میدی', datetime.timedelta(seconds=342, microseconds=500000)), ('حفظ روحیه کنی روحیه تو حفظ کنی و بتونی به نوعی خودتو حفظ کنی و بری جلو که میشه مسیر چهار و پنج یک خودتو آروم نگه داری شر ...
# Persian translation saved to S (3).wav.docx
# 🎉 All files processed!
